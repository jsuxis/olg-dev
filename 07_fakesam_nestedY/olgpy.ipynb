# %%
import gdxpds
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import rcParams

sourcepath1 = 'C:/Users/Manu/Documents/olg/07_fakesam_nestedY'
picpath = 'C:/Users/Manu/Documents/olg/07_fakesam_nestedY'

rcParams['figure.figsize'] = 15, 5
gdx_file = sourcepath1+'/results_dem1.gdx'
gdx_file2 = sourcepath1+'/results_dem2.gdx'
gdx_file3 = sourcepath1+'/results_prod.gdx'
dataframes = gdxpds.to_dataframes(gdx_file)
dataframes2 = gdxpds.to_dataframes(gdx_file2)
dataframes3 = gdxpds.to_dataframes(gdx_file3)

# %%
Y = dataframes['Y']
Y['Level2'] = dataframes2['Y']['Level']
Y['Level3'] = dataframes3['Y']['Level']


macrovariables = ['K','I','Bond','Rent','Rint']
macro = {}
for v in macrovariables:
    macro[v] = dataframes[v]
    macro[v]['Level2'] = dataframes2[v]['Level']
    macro[v]['Level3'] = dataframes3[v]['Level']

# %%
Y1 = Y[Y['s'] == 's1']
Y2 = Y[Y['s'] == 's2']
Y3 = Y[Y['s'] == 's3']
Y4 = Y[Y['s'] == 's4']
Y5 = Y[Y['s'] == 's5']
Y6 = Y[Y['s'] == 's6']
Y7 = Y[Y['s'] == 's7']
#Y8 = Y[Y['s'] == 's8']
    
Yi = [Y1,Y2,Y3,Y4,Y5,Y6,Y7]
for i in Yi:
    fig = plt.figure()
    ax  = fig.add_subplot(1, 1, 1)
    ax.set_ylabel(i.s.iloc[0], color='black') 
    ax.tick_params(axis='x', colors='black')
    ax.tick_params(axis='y', colors='black')
    plt.plot(i.t,i.Level, label='Baby Boom') 
    plt.plot(i.t, i.Level2, label='Baby Boom and Bust')
    plt.plot(i.t, i.Level3, label='Productivity Sector 1 increases')
    ax.axvline('t4', color='k', linestyle='--')
    ax.axvline('t10', color='k', linestyle='--')
    plt.legend(loc='upper right')
    plt.savefig(picpath+'/Y'+str(i.s.iloc[0])+'.png')

# %%
for v in macrovariables:
    fig = plt.figure()
    ax  = fig.add_subplot(1, 1, 1)
    ax.set_ylabel(v, color='black') 
    ax.tick_params(axis='x', colors='black')
    ax.tick_params(axis='y', colors='black')
    
    plt.plot(macro[v].t,macro[v].Level, label='Baby Boom') 
    plt.plot(macro[v].t,macro[v].Level2, label='Baby Boom and Bust')
    plt.plot(macro[v].t,macro[v].Level3, label='Productivity Sector 1 increases')
    ax.axvline('t4', color='k', linestyle='--')
    ax.axvline('t10', color='k', linestyle='--')
    plt.legend(loc='upper right')
    plt.savefig(picpath+'/plot'+str(v)+'.png')

# %%
fig = plt.figure()
ax  = fig.add_subplot(1, 1, 1)
ax.set_ylabel('Q', color='white') 
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.axvline('t4', color='k', linestyle='--')
ax.axvline('t10', color='k', linestyle='--')
Q = Y.groupby(['t'], sort=False)['Level'].sum()
Q2 = Y.groupby(['t'], sort=False)['Level2'].sum()
Q3 = Y.groupby(['t'], sort=False)['Level3'].sum()
Q.plot()
Q2.plot()
Q3.plot()
plt.savefig(picpath+'/plotY.png')

# %%
Y.groupby(['t'], sort=False)['Level'].sum()
# Out:
# t
# t1     727.500000
# t2     727.500000
# t3     727.500000
# t4     727.563786
# t5     727.267460
# t6     727.425940
# t7     727.786057
# t8     728.450972
# t9     729.262719
# t10    728.811622
# t11    727.866155
# t12    711.862536
# t13    771.482306
# t14    950.957890
# t15    807.791266
# t16    792.861758
# t17    755.129016
# t18    756.262220
# t19    737.156168
# t20    734.497176
# t21    728.033340
# t22    728.180520
# t23    726.185079
# t24    729.635712
# t25    727.909069
# t26    730.225155
# t27    727.866207
# t28    729.745404
# t29    729.547334
# t30    729.782778
# t31    729.443095
# t32    730.691836
# t33    730.322706
# t34    730.398709
# t35    730.290254
# t36    730.443569
# t37    730.292039
# t38    730.312863
# t39    730.224037
# t40    730.254977
# t41    730.173967
# t42    730.234363
# t43    730.178254
# t44    730.245643
# t45    730.194124
# t46    730.278473
# t47    730.509338
# t48    730.168196
# t49    730.188378
# t50    727.500000
# Name: Level, dtype: float64
